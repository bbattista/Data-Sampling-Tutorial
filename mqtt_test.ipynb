# %%
import sqlite3

# SQLite DB Name
DB_Name =  "devices.db"

# SQLite DB Table Schema
deviceTableSchema="""
DROP TABLE IF EXISTS devices ;
CREATE TABLE devices (
  id integer primary key autoincrement,
  SensorID text,
  tst,
  datetime text,
  lon,
  lat,
  raw
);

CREATE TRIGGER IF NOT EXISTS format_datetime AFTER INSERT ON devices
  BEGIN
    UPDATE devices SET datetime = strftime('%Y-%m-%d %H:%M:%S', DATETIME(NEW.tst, 'unixepoch', 'localtime')) WHERE id=NEW.id;
  END;
"""

# SQLite DB Table Schema
configTableSchema="""
DROP TABLE IF EXISTS config ;
CREATE TABLE config (
  id integer primary key autoincrement,
  SensorID text,
  datetime text,
  company text,
  project text,
  vessel text,
  projection text,
  units text,
  xteType text
);

CREATE TRIGGER IF NOT EXISTS config_datetime AFTER INSERT ON config
  BEGIN
    UPDATE config SET datetime = datetime('now','localtime') WHERE id=NEW.id;
  END;
"""

# SQLite DB Table Schema
calibrateTableSchema="""
DROP TABLE IF EXISTS calibration ;
CREATE TABLE calibration (
  id integer primary key autoincrement,
  SensorID text,
  datetime text,
  project text,
  vessel text,
  length,
  width,
  height,
  cutterLength,
  cutterDraft,
  pinOffX,
  pinOffY,
  pinOffZ,
  gpsOffX,
  gpsOffY,
  gpsOffZ,
  hdgOffX,
  hdgOffY,
  hdgOffZ,
  flipAngleX,
  flipAngleY
);

CREATE TRIGGER IF NOT EXISTS cal_datetime AFTER INSERT ON calibration
  BEGIN
    UPDATE calibration SET datetime = datetime('now','localtime') WHERE id=NEW.id;
  END;
"""

#Connect or Create DB File
conn = sqlite3.connect(DB_Name)
curs = conn.cursor()

#Create Tables
sqlite3.complete_statement(deviceTableSchema)
curs.executescript(deviceTableSchema)

sqlite3.complete_statement(configTableSchema)
curs.executescript(configTableSchema)

sqlite3.complete_statement(calibrateTableSchema)
curs.executescript(calibrateTableSchema)

#Close DB
curs.close()
conn.close()

# %%
import paho.mqtt.client as mqtt
import configparser
import time
import datetime
import json
from log_to_db import device_Data_Handler

# %%
# Read Config File
config = configparser.ConfigParser()
config.read('mqtt_logger.conf')
config.sections()
projConf = config['PROJECT']
project = projConf['project']

# MQTT Settings
MQTTconf = config['MQTT']
MQTT_Broker = MQTTconf['MQTT_Broker']
MQTT_Port = int(MQTTconf['MQTT_Port'])
Keep_Alive_Interval = int(MQTTconf['Keep_Alive_Interval'])
MQTT_Topic = project + '/#'
username = MQTTconf['username']
password = MQTTconf['password']

# %%
#Subscribe to all Sensors at Base Topic
def on_connect(mosq, obj, flags, rc):
    mqttc.subscribe(MQTT_Topic, 0)

#Save Data into DB Table
def on_message(mosq, obj, msg):
    # This is the Master Call for saving MQTT Data into DB
    # For details of "sensor_Data_Handler" function please refer "sensor_data_to_db.py"
    msg.payload = msg.payload.decode('utf-8')
    result=0

    timestamp = datetime.datetime.now()

    print("MQTT Data Received (%s)..." % timestamp)
    print("MQTT Topic: " + msg.topic)
    print("Data: " + msg.payload)

    try:
        result = device_Data_Handler(msg.topic, msg.payload)
    except:
        print("Database log entry unsuccessful.")

    if (result):
        topic = result['project'] + '/' + result['vessel'] + '/import'
        mqttc.publish(topic, payload=json.dumps(result), qos=1, retain=False)

def on_subscribe(mosq, obj, mid, granted_qos):
    pass

def on_publish(client, userdata, mid):
    pass

# %%
#create an mqtt client
clientID = "dredgenav-"+"%s" % time.time()
mqttc = mqtt.Client(clientID, clean_session=False)
#mqttc = mqtt.Client(clientID)
mqttc.username_pw_set(username,password)

# Assign event callbacks
mqttc.on_message = on_message
mqttc.on_connect = on_connect
mqttc.on_subscribe = on_subscribe
mqttc.on_publish = on_publish

# Connect
mqttc.connect(MQTT_Broker, int(MQTT_Port), int(Keep_Alive_Interval))

# Continue the network loop
mqttc.loop_forever()
# Out:
# MQTT Data Received (2021-03-23 01:07:12.934158)...
# MQTT Topic: brook/brk202/gps
# Data: {"tst": 1616490432.0, "nmea": true, "lon": -78.95636166666667, "lat": 36.07998166666667, "t": "u", "_type": "location", "tid": "brk202", "fix_stat": 2, "num_sats": 14, "cog": 145.97, "speed": 0.0, "altitude": 147.0, "geoid_height": -32.9, "hdop": 0.78}
# Inserted Data into Devices.
#
# MQTT Data Received (2021-03-23 01:07:12.960120)...
# MQTT Topic: brook/brk202/hdg
# Data: {"tst": 1616490432.0, "nmea": true, "lon": -78.95643666666666, "lat": 36.07995666666667, "t": "u", "_type": "hdgSensor", "tid": "brk202", "fix_stat": 2, "num_sats": 17, "altitude": 156.1, "geoid_height": -32.9, "hdop": 0.6}
# MQTT Data Received (2021-03-23 01:07:12.960539)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18518, "depth": 38.919000000000004, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:12.960899)...
# MQTT Topic: brook/brk202/angle
# Data: {"_type": "angleSensor", "tid": "brk202", "mode": "A", "nodeID": "1", "X": "0004", "Y": 0, "rotation": 0}
# MQTT Data Received (2021-03-23 01:07:12.961198)...
# MQTT Topic: brook/brk208/gps
# Data: {"tst": 1612131147.0, "nmea": true, "lon": -78.95649, "lat": 36.07987333333333, "t": "u", "_type": "location", "tid": "brk208", "fix_stat": 2, "num_sats": 13, "cog": 198.25, "speed": 0.0, "altitude": 140.1, "geoid_height": -32.9, "hdop": 0.8}
# Inserted Data into Devices.
#
# MQTT Data Received (2021-03-23 01:07:13.041426)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18519, "depth": 39.265, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:13.299500)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18520, "depth": 39.012, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:13.404739)...
# MQTT Topic: brook/brk202/gps
# Data: {"tst": 1616490433.0, "nmea": true, "lon": -78.95636166666667, "lat": 36.07998166666667, "t": "u", "_type": "location", "tid": "brk202", "fix_stat": 2, "num_sats": 14, "cog": 145.97, "speed": 0.0, "altitude": 147.0, "geoid_height": -32.9, "hdop": 0.78}
# Inserted Data into Devices.
#
# MQTT Data Received (2021-03-23 01:07:13.479975)...
# MQTT Topic: brook/brk202/hdg
# Data: {"tst": 1616490433.0, "nmea": true, "lon": -78.95643666666666, "lat": 36.07995666666667, "t": "u", "_type": "hdgSensor", "tid": "brk202", "fix_stat": 2, "num_sats": 17, "altitude": 156.1, "geoid_height": -32.9, "hdop": 0.6}
# MQTT Data Received (2021-03-23 01:07:13.549982)...
# MQTT Topic: brook/brk202/angle
# Data: {"_type": "angleSensor", "tid": "brk202", "mode": "A", "nodeID": "1", "X": "0003", "Y": 0, "rotation": 0}
# MQTT Data Received (2021-03-23 01:07:13.615070)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18521, "depth": 39.097, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:13.678483)...
# MQTT Topic: brook/brk202/angle
# Data: {"_type": "angleSensor", "tid": "brk202", "mode": "A", "nodeID": "1", "X": "0004", "Y": 0, "rotation": 0}
# MQTT Data Received (2021-03-23 01:07:13.801256)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18522, "depth": 38.725, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:14.060495)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18523, "depth": 38.883, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:14.320256)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18524, "depth": 39.161, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:14.400516)...
# MQTT Topic: brook/brk202/gps
# Data: {"tst": 1616490434.0, "nmea": true, "lon": -78.95636166666667, "lat": 36.07998166666667, "t": "u", "_type": "location", "tid": "brk202", "fix_stat": 2, "num_sats": 14, "cog": 145.97, "speed": 0.0, "altitude": 147.0, "geoid_height": -32.9, "hdop": 0.78}
# Inserted Data into Devices.
#
# MQTT Data Received (2021-03-23 01:07:14.469980)...
# MQTT Topic: brook/brk202/hdg
# Data: {"tst": 1616490434.0, "nmea": true, "lon": -78.95643666666666, "lat": 36.07995666666667, "t": "u", "_type": "hdgSensor", "tid": "brk202", "fix_stat": 2, "num_sats": 17, "altitude": 156.1, "geoid_height": -32.9, "hdop": 0.6}
# MQTT Data Received (2021-03-23 01:07:14.565493)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18525, "depth": 39.499, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:14.819744)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18526, "depth": 35.584, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:15.080009)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18527, "depth": 34.894, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:15.325020)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18528, "depth": 33.801, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:15.395244)...
# MQTT Topic: brook/brk202/gps
# Data: {"tst": 1616490435.0, "nmea": true, "lon": -78.95636166666667, "lat": 36.07998166666667, "t": "u", "_type": "location", "tid": "brk202", "fix_stat": 2, "num_sats": 14, "cog": 145.97, "speed": 0.0, "altitude": 147.0, "geoid_height": -32.9, "hdop": 0.78}
# Inserted Data into Devices.
#
# MQTT Data Received (2021-03-23 01:07:15.461015)...
# MQTT Topic: brook/brk202/hdg
# Data: {"tst": 1616490435.0, "nmea": true, "lon": -78.95643666666666, "lat": 36.07995666666667, "t": "u", "_type": "hdgSensor", "tid": "brk202", "fix_stat": 2, "num_sats": 17, "altitude": 156.1, "geoid_height": -32.9, "hdop": 0.6}
# MQTT Data Received (2021-03-23 01:07:15.573171)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18529, "depth": 39.454, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:15.830255)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18530, "depth": 39.538000000000004, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:16.090256)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18531, "depth": 39.513, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:16.348480)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18532, "depth": 32.294000000000004, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# MQTT Data Received (2021-03-23 01:07:16.414239)...
# MQTT Topic: brook/brk202/gps
# Data: {"tst": 1616490436.0, "nmea": true, "lon": -78.95636166666667, "lat": 36.07998166666667, "t": "u", "_type": "location", "tid": "brk202", "fix_stat": 2, "num_sats": 14, "cog": 145.97, "speed": 0.0, "altitude": 147.0, "geoid_height": -32.9, "hdop": 0.78}
# Inserted Data into Devices.
#
# MQTT Data Received (2021-03-23 01:07:16.481101)...
# MQTT Topic: brook/brk202/hdg
# Data: {"tst": 1616490436.0, "nmea": true, "lon": -78.95643666666666, "lat": 36.07995666666667, "t": "u", "_type": "hdgSensor", "tid": "brk202", "fix_stat": 2, "num_sats": 17, "altitude": 156.1, "geoid_height": -32.9, "hdop": 0.6}
# MQTT Data Received (2021-03-23 01:07:16.598503)...
# MQTT Topic: brook/brk202/sonar
# Data: {"_type": "sonar", "tid": "brk202", "ping": 18533, "depth": 39.101, "confidence": 0, "pulse_len": 1173, "gain": 6, "start": 0.0, "length": 42.544000000000004, "temp": 29.310000000000002}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7bcf5637ad47> in <module>
#      15
#      16 # Continue the network loop
# ---> 17 mqttc.loop_forever()
#
# /usr/local/lib/python3.6/dist-packages/paho/mqtt/client.py in loop_forever(self, timeout, max_packets, retry_first_connection)
#    1777             rc = MQTT_ERR_SUCCESS
#    1778             while rc == MQTT_ERR_SUCCESS:
# -> 1779                 rc = self.loop(timeout, max_packets)
#    1780                 # We don't need to worry about locking here, because we've
#    1781                 # either called loop_forever() when in single threaded mode, or
#
# /usr/local/lib/python3.6/dist-packages/paho/mqtt/client.py in loop(self, timeout, max_packets)
#    1165         rlist = [self._sock, self._sockpairR]
#    1166         try:
# -> 1167             socklist = select.select(rlist, wlist, [], timeout)
#    1168         except TypeError:
#    1169             # Socket isn't correct type, in likelihood connection is lost
#
# KeyboardInterrupt:
